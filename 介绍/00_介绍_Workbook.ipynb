# %% [markdown]
# <a href="https://colab.research.google.com/github/unpackAI/CDL101/blob/main/%E4%BB%8B%E7%BB%8D/00_%E4%BB%8B%E7%BB%8D_Workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻unpackAI "DL101训练营 "的第0周工作手册
#
# ##第0周的可交付成果
#
# 我们非常关注你是否完成了下列所有的作业。你将被要求在下一节课上展示这些作业的完成情况和理解。
#
# ## 📕学习目标
#
# * 复习第0周所学的内容并使之概念化。
# * 巩固你在AI/ML方面的理论基础。

# %%
#@title 运行这个单元来安装我们需要的所有库（技术包）。
# !pip install -Uqq fastbook
from fastbook import *
# Out:
#      |████████████████████████████████| 720 kB 4.1 MB/s
#      |████████████████████████████████| 189 kB 49.5 MB/s
#      |████████████████████████████████| 46 kB 4.3 MB/s
#      |████████████████████████████████| 1.2 MB 40.5 MB/s
#      |████████████████████████████████| 56 kB 4.9 MB/s
#      |████████████████████████████████| 51 kB 362 kB/s

# %% [markdown]
# ## unpackAI作业部分
#
# * **作业1**。仔细阅读以下问题，研究并写下你的答案。
# > 准备好在与小组讨论的发言环节中回答这些问题。
# * **作业2**: 准备用你自己的话来口头描述深度学习过程。在描述的同时提供一个实际的例子。
# > 准备在报告会上介绍。

# %% [markdown]
# ## **作业1：**浏览以下问题，研究并写下你的答案。

# %% [markdown]
# 1. 人工智能、机器学习和深度学习之间的区别是什么？

# %% [markdown]
# ## **作业2：**准备用自己的话口头描述深度学习过程。

# %% [markdown]
# 下面是我们在教材中描述的深度学习模型训练过程。请确保理解每个步骤以及它们之间的关系。

# %%
#@title
matplotlib.rc('image', cmap='Greys')
gv('''ordering=in
model[shape=box3d width=1 height=0.7 label="神经网络 + 参数"]
输入->model->预测; 标签->损失; 预测->损失
损失->model[constraint=false label=更新]''')

# %% [markdown]
# ## **作业3：**想出个人用例，如何利用深度学习为你服务。

# %% [markdown]
# 以你目前对5个应用领域的理解，想想你会在工作中或出于个人兴趣建立什么应用。
#
# |领域|定义|我的用例|
# |:---| :--- | :--- |
# 计算机视觉|使计算机和系统能够从数字图像、视频和其他视觉输入中得出有意义的信息。|由你来补充
# 表格式数据|表格式数据是指结构化为行的数据，每一行都包含了关于某些事物的信息。|由你来补充
# 推荐系统|旨在向用户推荐相关项目的算法。|由你来补充
# 自然语言处理（NLP）|以与人类相同的方式理解和响应文本或语音数据的机器。|由你来补充

# %% [markdown]
# ## 笔记本结束
#
# 你已经完成了unpackAI Bootcamp第一周的可交付成果。你们正在取得进展! 我们很高兴看到你的成果，并在即将到来的导师会议上测试你。
